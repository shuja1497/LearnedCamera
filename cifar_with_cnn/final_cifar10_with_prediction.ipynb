# %% [markdown]
# # Object recognition on cifar10 dataset using CNN

# %% [markdown]
# ###### Using keras to import  cifar10 dataset

# %%
from keras.datasets import cifar10
from matplotlib import pyplot as plt

# %% [markdown]
# ###### Loading data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train[i])
# show the plot
plt.show()

# %%
print  X_train.shape ,  y_train.shape
print X_test.shape , y_test.shape
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
print 'training data:', X_train.shape[0]
print 'test data:' , X_test.shape[0]
# Out:
# training data: 50000
# test data: 10000

# %%
print "dimension of a single image :", X_train[1].shape
# Out:
# dimension of a single image : (32, 32, 3)

# %% [markdown]
# ###### 32*32 dimensions with 3 channels ->RGB

# %%
print "for first channel :"
print X_train[1][:,:,0]
# Out:
# for first channel :
# [[154 126 105 ...,  91  87  79]
#  [140 145 125 ...,  96  77  71]
#  [140 139 115 ...,  79  68  67]
#  ...,
#  [175 156 154 ...,  42  61  93]
#  [165 156 159 ..., 103 123 131]
#  [163 158 163 ..., 143 143 143]]

# %% [markdown]
# ###### importing libraries for model contruction

# %%
import numpy as np
from keras.callbacks import EarlyStopping
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import np_utils

# %%
num_classes = 10
epochs = 200
data_augmentation = False
num_predictions = 30
batch_size = 128

# %% [markdown]
# ###### Data Preprocessing like normalization and  one hot vectorization

# %%
X_train = X_train/255.0
X_test = X_test/255.0

y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test , num_classes)

# %%
print "normalized pixel values  for first channel :\n\n" , X_train[1][: , : , 0]
# Out:
# normalized pixel values  for first channel :
#
# [[ 0.60392157  0.49411765  0.41176471 ...,  0.35686275  0.34117647
#    0.30980392]
#  [ 0.54901961  0.56862745  0.49019608 ...,  0.37647059  0.30196078
#    0.27843137]
#  [ 0.54901961  0.54509804  0.45098039 ...,  0.30980392  0.26666667
#    0.2627451 ]
#  ...,
#  [ 0.68627451  0.61176471  0.60392157 ...,  0.16470588  0.23921569
#    0.36470588]
#  [ 0.64705882  0.61176471  0.62352941 ...,  0.40392157  0.48235294
#    0.51372549]
#  [ 0.63921569  0.61960784  0.63921569 ...,  0.56078431  0.56078431
#    0.56078431]]

# %%
print "new shape for y-train :",  y_train.shape
# Out:
# new shape for y-train : (50000, 10)

# %% [markdown]
# ###### Creating the Model

# %%
model = Sequential()

model.add(Conv2D(32,(3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# ######  Summary of the Model

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 776,394
# Trainable params: 776,394
# Non-trainable params: 0
# _________________________________________________________________

# %%
print len(model.get_weights())
# Out:
# 12

# %% [markdown]
# ### Model Visualization

# %%
# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot
# SVG(model_to_dot(model).create(prog='dot', format='svg'))
# # from keras.utils import plot_model
# # plot_model(model, to_file='model.png')

# %% [markdown]
# ###### Initiating adams optimizer

# %%
opt  = Adam(lr=0.0001, decay=1e-6)

# %% [markdown]
# ###### Compiling the Model

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])

# %% [markdown]
# ###### Fitting the Model

# %%
if not data_augmentation:
    print('Not using data augmentation.')
    hist = model.fit(X_train, y_train,
              batch_size=batch_size,
              nb_epoch=epochs,
              validation_data=(X_test, y_test),
              callbacks=[EarlyStopping(min_delta=0.001, patience=3)],
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False) # randomly flip images

        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(X_train)

        # Fit the model on the batches generated by datagen.flow().
    hist_with_augmentation = model.fit_generator(datagen.flow(X_train, y_train,
                                batch_size=batch_size),
                                samples_per_epoch=x_train.shape[0] // batch_size,
                                nb_epoch=epochs, validation_data = (X_test, y_test),
                       callbacks=[EarlyStopping(min_delta=0.001, patience=3)])
# Out:
# Not using data augmentation.
# /home/shuja1497/anaconda2/lib/python2.7/site-packages/keras/models.py:851: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 259s - loss: 1.9651 - acc: 0.2656 - val_loss: 1.7157 - val_acc: 0.3801
# Epoch 2/200
# 50000/50000 [==============================] - 276s - loss: 1.6683 - acc: 0.3799 - val_loss: 1.5611 - val_acc: 0.4280
# Epoch 3/200
# 50000/50000 [==============================] - 285s - loss: 1.5290 - acc: 0.4380 - val_loss: 1.4093 - val_acc: 0.4881
# Epoch 4/200
# 50000/50000 [==============================] - 296s - loss: 1.4340 - acc: 0.4790 - val_loss: 1.3632 - val_acc: 0.5056
# Epoch 5/200
# 50000/50000 [==============================] - 295s - loss: 1.3633 - acc: 0.5077 - val_loss: 1.2585 - val_acc: 0.5532
# Epoch 6/200
# 50000/50000 [==============================] - 296s - loss: 1.2983 - acc: 0.5335 - val_loss: 1.2027 - val_acc: 0.5735
# Epoch 7/200
# 50000/50000 [==============================] - 302s - loss: 1.2479 - acc: 0.5527 - val_loss: 1.1728 - val_acc: 0.5868
# Epoch 8/200
# 50000/50000 [==============================] - 292s - loss: 1.1976 - acc: 0.5736 - val_loss: 1.1105 - val_acc: 0.6069
# Epoch 9/200
# 50000/50000 [==============================] - 303s - loss: 1.1563 - acc: 0.5895 - val_loss: 1.0961 - val_acc: 0.6139
# Epoch 10/200
# 50000/50000 [==============================] - 312s - loss: 1.1135 - acc: 0.6057 - val_loss: 1.0465 - val_acc: 0.6376
# Epoch 11/200
# 50000/50000 [==============================] - 308s - loss: 1.0820 - acc: 0.6169 - val_loss: 1.0200 - val_acc: 0.6434
# Epoch 12/200
# 50000/50000 [==============================] - 293s - loss: 1.0524 - acc: 0.6288 - val_loss: 0.9846 - val_acc: 0.6558
# Epoch 13/200
# 50000/50000 [==============================] - 317s - loss: 1.0248 - acc: 0.6401 - val_loss: 0.9504 - val_acc: 0.6683
# Epoch 14/200
# 50000/50000 [==============================] - 325s - loss: 0.9953 - acc: 0.6491 - val_loss: 0.9358 - val_acc: 0.6763
# Epoch 15/200
# 50000/50000 [==============================] - 336s - loss: 0.9752 - acc: 0.6566 - val_loss: 0.9225 - val_acc: 0.6791
# Epoch 16/200
# 50000/50000 [==============================] - 335s - loss: 0.9528 - acc: 0.6665 - val_loss: 0.9073 - val_acc: 0.6840
# Epoch 17/200
# 50000/50000 [==============================] - 300s - loss: 0.9239 - acc: 0.6742 - val_loss: 0.8760 - val_acc: 0.6951
# Epoch 18/200
# 50000/50000 [==============================] - 294s - loss: 0.9080 - acc: 0.6821 - val_loss: 0.8516 - val_acc: 0.7061
# Epoch 19/200
# 50000/50000 [==============================] - 291s - loss: 0.8900 - acc: 0.6860 - val_loss: 0.8472 - val_acc: 0.7047
# Epoch 20/200
# 50000/50000 [==============================] - 291s - loss: 0.8700 - acc: 0.6944 - val_loss: 0.8302 - val_acc: 0.7128
# Epoch 21/200
# 50000/50000 [==============================] - 292s - loss: 0.8556 - acc: 0.6984 - val_loss: 0.8160 - val_acc: 0.7140
# Epoch 22/200
# 50000/50000 [==============================] - 286s - loss: 0.8382 - acc: 0.7042 - val_loss: 0.8026 - val_acc: 0.7189
# Epoch 23/200
# 50000/50000 [==============================] - 287s - loss: 0.8191 - acc: 0.7112 - val_loss: 0.7991 - val_acc: 0.7200
# Epoch 24/200
# 50000/50000 [==============================] - 285s - loss: 0.8037 - acc: 0.7206 - val_loss: 0.7751 - val_acc: 0.7310
# Epoch 25/200
# 50000/50000 [==============================] - 285s - loss: 0.7920 - acc: 0.7214 - val_loss: 0.7620 - val_acc: 0.7327
# Epoch 26/200
# 50000/50000 [==============================] - 282s - loss: 0.7785 - acc: 0.7282 - val_loss: 0.7616 - val_acc: 0.7334
# Epoch 27/200
# 50000/50000 [==============================] - 288s - loss: 0.7666 - acc: 0.7316 - val_loss: 0.7501 - val_acc: 0.7348
# Epoch 28/200
# 50000/50000 [==============================] - 298s - loss: 0.7563 - acc: 0.7345 - val_loss: 0.7341 - val_acc: 0.7403
# Epoch 29/200
# 50000/50000 [==============================] - 305s - loss: 0.7398 - acc: 0.7431 - val_loss: 0.7274 - val_acc: 0.7439
# Epoch 30/200
# 50000/50000 [==============================] - 291s - loss: 0.7272 - acc: 0.7459 - val_loss: 0.7207 - val_acc: 0.7471
# Epoch 31/200
# 50000/50000 [==============================] - 313s - loss: 0.7182 - acc: 0.7498 - val_loss: 0.7206 - val_acc: 0.7471
# Epoch 32/200
# 50000/50000 [==============================] - 310s - loss: 0.7046 - acc: 0.7521 - val_loss: 0.7058 - val_acc: 0.7495
# Epoch 33/200
# 50000/50000 [==============================] - 317s - loss: 0.6937 - acc: 0.7568 - val_loss: 0.7092 - val_acc: 0.7513
# Epoch 34/200
# 50000/50000 [==============================] - 301s - loss: 0.6798 - acc: 0.7602 - val_loss: 0.6891 - val_acc: 0.7548
# Epoch 35/200
# 50000/50000 [==============================] - 297s - loss: 0.6748 - acc: 0.7638 - val_loss: 0.6893 - val_acc: 0.7567
# Epoch 36/200
# 50000/50000 [==============================] - 308s - loss: 0.6630 - acc: 0.7687 - val_loss: 0.6861 - val_acc: 0.7574
# Epoch 37/200
# 50000/50000 [==============================] - 315s - loss: 0.6532 - acc: 0.7694 - val_loss: 0.6803 - val_acc: 0.7597
# Epoch 38/200
# 50000/50000 [==============================] - 307s - loss: 0.6468 - acc: 0.7745 - val_loss: 0.6767 - val_acc: 0.7586
# Epoch 39/200
# 50000/50000 [==============================] - 308s - loss: 0.6348 - acc: 0.7769 - val_loss: 0.6775 - val_acc: 0.7592
# Epoch 40/200
# 50000/50000 [==============================] - 311s - loss: 0.6232 - acc: 0.7818 - val_loss: 0.6737 - val_acc: 0.7634
# Epoch 41/200
# 50000/50000 [==============================] - 325s - loss: 0.6213 - acc: 0.7829 - val_loss: 0.6561 - val_acc: 0.7700
# Epoch 42/200
# 50000/50000 [==============================] - 304s - loss: 0.6136 - acc: 0.7825 - val_loss: 0.6536 - val_acc: 0.7660
# Epoch 43/200
# 50000/50000 [==============================] - 304s - loss: 0.6016 - acc: 0.7892 - val_loss: 0.6563 - val_acc: 0.7678
# Epoch 44/200
# 50000/50000 [==============================] - 280s - loss: 0.5918 - acc: 0.7914 - val_loss: 0.6474 - val_acc: 0.7702
# Epoch 45/200
# 50000/50000 [==============================] - 281s - loss: 0.5905 - acc: 0.7928 - val_loss: 0.6362 - val_acc: 0.7739
# Epoch 46/200
# 50000/50000 [==============================] - 279s - loss: 0.5780 - acc: 0.7969 - val_loss: 0.6354 - val_acc: 0.7779
# Epoch 47/200
# 50000/50000 [==============================] - 278s - loss: 0.5710 - acc: 0.8008 - val_loss: 0.6373 - val_acc: 0.7770
# Epoch 48/200
# 50000/50000 [==============================] - 287s - loss: 0.5639 - acc: 0.8020 - val_loss: 0.6430 - val_acc: 0.7698
# Epoch 49/200
# 50000/50000 [==============================] - 281s - loss: 0.5538 - acc: 0.8060 - val_loss: 0.6390 - val_acc: 0.7777

# %% [markdown]
#       The validation accuracy reaches 0.79 after 60 epochs when the early stopping terminates the process because the  validation loss has stopped decreasing (the final value is about 0.6).

# %% [markdown]
# ###### the above model reaches an accuracy of around 79% with 60 epochs having a batch size of 128 and the optimizer being used is adam's optimizer

# %% [markdown]
# ###### model evaluation :

# %%
scores = model.evaluate(X_test , y_test)
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
#  9984/10000 [============================>.] - ETA: 0sLoss: 0.639
# Accuracy: 0.778

# %%
h_data = hist.history

# %%
print h_data
print h_data.keys()
# Out:
# {'acc': [0.26559999998092654, 0.37994000001907346, 0.43799999999046324, 0.47902, 0.50774000001907349, 0.53354000003814694, 0.55270000001907349, 0.573560000038147, 0.58949999996185298, 0.60566000003814702, 0.61685999996185303, 0.62879999998092651, 0.64012000000000002, 0.64905999996185304, 0.65659999999046326, 0.66650000003814702, 0.67418, 0.68208000001907354, 0.68600000000000005, 0.69443999996185302, 0.69842000000000004, 0.70420000000000005, 0.71120000003814698, 0.72063999998092654, 0.72140000001907345, 0.72816000000000003, 0.73162000000000005, 0.73454000001907349, 0.74307999998092655, 0.74587999999999999, 0.7497600000190735, 0.75212000003814694, 0.75678000001907353, 0.76018000003814701, 0.76376000003814692, 0.76869999996185301, 0.76937999996185302, 0.77447999999999995, 0.77689999996185299, 0.78183999996185305, 0.78286000001907352, 0.78247999996185302, 0.78917999998092647, 0.79143999998092651, 0.79283999996185306, 0.79690000001907346, 0.80079999996185303, 0.80201999996185303, 0.80603999999999998], 'loss': [1.9650805690765381, 1.6682909295654298, 1.5290405266571045, 1.434007339477539, 1.3632661191177369, 1.2982807702636718, 1.2479265790939331, 1.1975929314422606, 1.1563415189361572, 1.1135488179779052, 1.0820435509109496, 1.0523655451202392, 1.0247815615081788, 0.99529104312896732, 0.97522562583923345, 0.95277520999908449, 0.92385262710571292, 0.90796656513214113, 0.88997835826873783, 0.87000150238037111, 0.85555322071075435, 0.83820973890304562, 0.81914070352554325, 0.80371943691253667, 0.7920161691474914, 0.77851415632247922, 0.76656450254440311, 0.75628728445053106, 0.73983333932876583, 0.72724888156890866, 0.71822475799560548, 0.70461337198257445, 0.6937136042404175, 0.67984663490295405, 0.67479980770111081, 0.66302347204208378, 0.65316344585418706, 0.64676647632598872, 0.63480901548385615, 0.62319324548721311, 0.62130614749908453, 0.61362846885681155, 0.60158359561920161, 0.59180410132408146, 0.59046369876861571, 0.57795122425079348, 0.57099594446182256, 0.56387417379379268, 0.55378198450088501], 'val_acc': [0.38009999999999999, 0.42799999999999999, 0.48809999999999998, 0.50560000000000005, 0.55320000000000003, 0.57350000000000001, 0.58679999999999999, 0.6069, 0.6139, 0.63759999999999994, 0.64339999999999997, 0.65580000000000005, 0.66830000000000001, 0.67630000000000001, 0.67910000000000004, 0.68400000000000005, 0.69510000000000005, 0.70609999999999995, 0.70469999999999999, 0.71279999999999999, 0.71399999999999997, 0.71889999999999998, 0.71999999999999997, 0.73099999999999998, 0.73270000000000002, 0.73340000000000005, 0.73480000000000001, 0.74029999999999996, 0.74390000000000001, 0.74709999999999999, 0.74709999999999999, 0.74950000000000006, 0.75129999999999997, 0.75480000000000003, 0.75670000000000004, 0.75739999999999996, 0.75970000000000004, 0.75860000000000005, 0.75919999999999999, 0.76339999999999997, 0.77000000000000002, 0.76600000000000001, 0.76780000000000004, 0.7702, 0.77390000000000003, 0.77790000000000004, 0.77700000000000002, 0.76980000000000004, 0.77769999999999995], 'val_loss': [1.715658373260498, 1.5611100206375121, 1.4092668426513673, 1.363195594215393, 1.258530510044098, 1.2027129793167115, 1.1727764637947082, 1.110524868774414, 1.0960995523452759, 1.0465102666854857, 1.0199993989944458, 0.98460630168914798, 0.95043118238449098, 0.93576890745162966, 0.9225310611724854, 0.90729261875152589, 0.87596697673797608, 0.85160600099563599, 0.84722364673614503, 0.83015138912200925, 0.81597901439666753, 0.80263231410980229, 0.79906774406433101, 0.77512953233718873, 0.76199172067642207, 0.76160470504760747, 0.75007281389236447, 0.73409327182769779, 0.72743888683319091, 0.72071441326141361, 0.72056823768615719, 0.70580446739196778, 0.70924134654998783, 0.6891217180252075, 0.68928967275619502, 0.68609912414550778, 0.68034500255584718, 0.67665350770950317, 0.67752847499847413, 0.67365434837341309, 0.65607940082550054, 0.65361310119628901, 0.65634349346160892, 0.64736035223007204, 0.63622706699371334, 0.6353779774665832, 0 ...
# ['acc', 'loss', 'val_acc', 'val_loss']

# %% [markdown]
# ## Visualization for loss and accuracy of the model

# %%
plt.figure(figsize=(14,3))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=16)

plt.plot(hist.history['loss'], 'b--', label='Training Loss', linewidth=3)
plt.plot(hist.history['val_loss'], 'r', label='Validation Loss' ,linewidth=3)
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.xlabel('Epochs', fontsize=16)
plt.plot(hist.history['acc'], 'b--', label='Training Accuracy' , linewidth=3)
plt.plot(hist.history['val_acc'], 'r', label='Validation Accuracy' , linewidth=3)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # For Model Testing

# %%
model.save('for_testing.h5')

# %%
from keras.models import load_model
# Out:
# Using TensorFlow backend.

# %%
model = load_model('for_testing.h5')

# %%
# save as JSON
json_string = model.to_json()

# save as YAML
yaml_string = model.to_yaml()

# %%
predicted_classes =  model.predict_classes(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5cbf81793fd5> in <module>()
# ----> 1 predicted_classes =  model.predict_classes(X_test)
#
# NameError: name 'X_test' is not defined

# %%
print predicted_classes[:20]

# %%
print model.predict(X_test)

# %%
import os
import pickle

label_list_path = 'datasets/cifar-10-batches-py/batches.meta'

keras_dir = os.path.expanduser(os.path.join('~', '.keras'))
datadir_base = os.path.expanduser(keras_dir)
if not os.access(datadir_base, os.W_OK):
    datadir_base = os.path.join('/tmp', '.keras')
label_list_path = os.path.join(datadir_base, label_list_path)

with open(label_list_path, mode='rb') as f:
    labels = pickle.load(f)

predict_gen = model.predict(X_test)

# %%
#testing for a single image
from keras.preprocessing import image as image_utils
test_image = image_utils.load_img('horse.jpg', target_size=(32, 32))
test_image = image_utils.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict_on_batch(test_image)


#print(result)
predicted_label = labels['label_names'][np.argmax(result)]
print(predicted_label)
# Out:
# horse

# %% [markdown]
# #### Prediction Analysis

# %%
import os
import pickle
import numpy as np

save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'final_cifar10_trained_model.h5'

# %% [markdown]
# ######  saving model in HDF5 file for prediction purpose

# %%
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /home/shujareshi/study/OpenSourceProject/cifar_with_cnn/saved_models/final_cifar10_trained_model.h5

# %% [markdown]
# ###### loading label names

# %%
label_list_path = 'datasets/cifar-10-batches-py/batches.meta'

# %%
keras_dir = os.path.expanduser(os.path.join('~', '.keras'))
datadir_base = os.path.expanduser(keras_dir)
if not os.access(datadir_base, os.W_OK):
    datadir_base = os.path.join('/tmp', '.keras')
label_list_path = os.path.join(datadir_base, label_list_path)

# %%
with open(label_list_path, mode='rb') as f:
    labels = pickle.load(f)

# %%
predict_gen = model.predict(X_test)
print predict_gen.shape
# Out:
# (10000, 10)

# %%
for predict_index, predicted_y in enumerate(predict_gen):
    actual_label = labels['label_names'][np.argmax(y_test[predict_index])]
    predicted_label = labels['label_names'][np.argmax(predicted_y)]
    print('Actual Label = %s vs. Predicted Label = %s' % (actual_label,
                                                          predicted_label))
    if predict_index == num_predictions:
        break
# Out:
# Actual Label = cat vs. Predicted Label = cat
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = airplane vs. Predicted Label = airplane
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = automobile vs. Predicted Label = automobile
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = cat vs. Predicted Label = cat
# Actual Label = automobile vs. Predicted Label = automobile
# Actual Label = airplane vs. Predicted Label = dog
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = dog vs. Predicted Label = cat
# Actual Label = horse vs. Predicted Label = horse
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = dog vs. Predicted Label = dog
# Actual Label = horse vs. Predicted Label = cat
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = horse vs. Predicted Label = horse
# Actual Label = airplane vs. Predicted Label = airplane
# Actual Label = deer vs. Predicted Label = deer
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = dog vs. Predicted Label = deer
# Actual Label = bird vs. Predicted Label = bird
# Actual Label = deer vs. Predicted Label = deer
# Actual Label = airplane vs. Predicted Label = airplane
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = frog vs. Predicted Label = frog

# %% [markdown]
# ###### Testing for a single image

# %%
#testing for a single image
from keras.preprocessing import image as image_utils
test_image = image_utils.load_img('dog.jpg', target_size=(32, 32))
test_image = image_utils.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict_on_batch(test_image)


#print(result)
predicted_label = labels['label_names'][np.argmax(result)]
print(predicted_label)
# Out:
# horse
